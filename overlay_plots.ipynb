# %%
from utils import *

# %%
# Overlay

# Fidelity Charts
path = f"./resources/output/fidelity_index_focused_models_model_ada1.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

fid_model_ada1 = dataframe

path = f"./resources/output/fidelity_index_focused_models_model_svm1.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

fid_model_svm1 = dataframe

path = f"./resources/output/fidelity_index_focused_models_annual.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

fid_annual = dataframe

path = f"./resources/output/fidelity_index_focused_models_monthly.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

fid_monthly = dataframe

# Betterment Charts
path = f"./resources/output/betterment_model_ada1.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

betterment_model_ada1 = dataframe

path = f"./resources/output/betterment_model_svm1.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

betterment_model_svm1 = dataframe

path = f"./resources/output/betterment_annual.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

betterment_annual = dataframe

path = f"./resources/output/betterment_monthly.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

betterment_monthly = dataframe

# Core 4 Charts
path = f"./resources/output/rick_ferris_core_model_ada1.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

core4_model_ada1 = dataframe

path = f"./resources/output/rick_ferris_core_model_svm1.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

core4_model_svm1 = dataframe

path = f"./resources/output/rick_ferris_core_annual.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

core4_annual = dataframe

path = f"./resources/output/rick_ferris_core_monthly.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

core4_monthly = dataframe

# VTI
path = f"./resources/output/vanguard_total_stock_etf_model_ada1.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

vti_model_ada1 = dataframe

path = f"./resources/output/vanguard_total_stock_etf_model_svm1.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

vti_model_svm1 = dataframe

path = f"./resources/output/vanguard_total_stock_etf_annual.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

vti_annual = dataframe

path = f"./resources/output/vanguard_total_stock_etf_monthly.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

vti_monthly = dataframe

# %%
# Plot

plot_portfolio = 'VTI'

x = {
    'Fidelity':[fid_monthly.index, fid_model_ada1.index, fid_annual.index, fid_model_svm1.index],
    'Betterment':[betterment_monthly.index, betterment_model_ada1.index, betterment_annual.index, betterment_model_svm1.index],
    'Core4':[core4_monthly.index, core4_model_ada1.index, core4_annual.index, core4_model_svm1.index],
    'VTI':[vti_monthly.index, vti_model_ada1.index, vti_annual.index, vti_model_svm1.index]
}

y = {
    'Fidelity':[fid_monthly.sum(axis=1), fid_model_ada1.sum(axis=1), fid_annual.sum(axis=1), fid_model_svm1.sum(axis=1)],
    'Betterment':[betterment_monthly.sum(axis=1), betterment_model_ada1.sum(axis=1), betterment_annual.sum(axis=1), betterment_model_svm1.sum(axis=1)],
    'Core4':[core4_monthly.sum(axis=1), core4_model_ada1.sum(axis=1), core4_annual.sum(axis=1), core4_model_svm1.sum(axis=1)],
    'VTI':[vti_monthly.sum(axis=1), vti_model_ada1.sum(axis=1), vti_annual.sum(axis=1), vti_model_svm1.sum(axis=1)]
}


fig = go.Figure()

fig.add_scatter(x=x[plot_portfolio][2], y=y[plot_portfolio][2].values, mode='lines', name='Annual')

fig.add_scatter(x=x[plot_portfolio][1], y=y[plot_portfolio][1].values, mode='lines', name='ADA Model 1m')

fig.add_scatter(x=x[plot_portfolio][0], y=y[plot_portfolio][0].values, mode='lines', name='Monthly')

fig.add_scatter(x=x[plot_portfolio][3], y=y[plot_portfolio][3].values, mode='lines', name='SVM Model 1m')

fig.update_layout(
    title=f'{plot_portfolio}',
    height=500,
    width=1000,
    xaxis_title="Year",
    yaxis_title="Account Balance",
    legend_title="Contribution Strategy",
    )

fig.show()

# %%
save_image(fig, f'./resources/images/{plot_portfolio}_overlay.png')
