# %%
from utils import *

# %%
# Global Variables

# %%
# Variable to set for application

# Select the portfolio to be invested in
# Options are fidelity_index_focused_models, betterment, rick_ferris_core and vanguard_total_stock_etf
portfolio_selection = 'betterment'
# portfolio_selection = 'fidelity_index_focused_models'
# portfolio_selection = 'rick_ferris_core'
# portfolio_selection = 'vanguard_total_stock_etf'

# Select timing of contributions
# Options are monthly, annual, model_ada1, model_svm1
timing = 'monthly'

# %%
# Load pkl files and set dfs

# IRA contribution limits
path = f"./resources/contribution_limits/ira_contribution_limits.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

ira_contr_limits = dataframe

# Portfolio
# Read in portfolio data from pkl file
path = f"./resources/portfolios/{portfolio_selection}.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()
         
# create portfolio allocation df for account setup and future rebalancing
selected_portfolio_weights = dataframe

# ML model predictions
path = './resources/predictions/portfolio_svm_predictions_1m.pkl'
pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

ml_model_1 = dataframe
ml_model_1.index = ml_model_1.index + BDay(1)

# ML model predictions
path = './resources/predictions/portfolio_ada_predictions_1m.pkl'
pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

ml_model_2 = dataframe
ml_model_2.index = ml_model_2.index + BDay(1)

# %%
# Transaction plan - annual, monthly, ML model 1, ML model 2
today = date.today()

# For annual
yearly_contr = pd.date_range(start='2013-01-01', end = today, freq='BAS')

# For monthly
monthly_contr = pd.date_range(start='2013-01-01', end = today, freq='BMS')

# library of timing options
investment_timing_idx = {
    'monthly': monthly_contr,
    'annual': yearly_contr,
    'model_svm': ml_model_1.index, 
    'model_ada': ml_model_2.index, 
}

investment_data_idx = {
    'monthly': len(monthly_contr)*[1],
    'annual': len(yearly_contr)*[12],
    'ml_model_1': ml_model_1['Months_To_Invest'].values,
    'ml_model_2': ml_model_2['Months_To_Invest'].values,
}

# %%
# Create initial df for investment dates
investment_dates = pd.DataFrame(
     index=investment_timing_idx[timing],
     data=investment_data_idx[timing],
     columns=['months_to_invest']
)

investment_dates.index = pd.to_datetime(investment_dates.index)
investment_dates
# Out:
#             months_to_invest
# 2013-01-01                 1
# 2013-02-01                 1
# 2013-03-01                 1
# 2013-04-01                 1
# 2013-05-01                 1
# ...                      ...
# 2022-05-02                 1
# 2022-06-01                 1
# 2022-07-01                 1
# 2022-08-01                 1
# 2022-09-01                 1
#
# [117 rows x 1 columns]

# %%
# Set up start dates

# Set the start date of the investment account
portfolio_investment_start_date = investment_dates.index[0]


# Set transaction range from portfolio start to today to include all business days
transaction_range = pd.date_range(
    start=pd.Timestamp(portfolio_investment_start_date), 
    end=today, 
    freq='B'
).tolist()

# %%
# This function sets up the new holding account for the IRA contribution amount to be held until contribution date(s) 
# This function also creates an investment account with a portfolio attached for investment and rebalancing

# Create a new holding account 
holding_account = 0

# variable to track holding account top ups
holding_acct_funded = None

# create new investment account with the selected portfolio funds as columns
investment_account = pd.DataFrame(columns=selected_portfolio_weights.columns.values)

debug_print(f'{portfolio_selection} has been attached to the new investment account.')
debug_print('The portfolio asset allocation is:')
debug_print(selected_portfolio_weights)
debug_print(f'The holding account balance is ${holding_account}.')
# Out:
# betterment has been attached to the new investment account.
# The portfolio asset allocation is:
#    VFIAX  VVIAX  VTMGX  VEMAX  VIMAX  VSMAX  VIPSX  VSBSX
# 0     15     15     15      6      5      4     20     20
# The holding account balance is $0.

# %%
# Create a dataframe of portfolio returns for the selected portfolio

portfolio_returns = portfolio_return(selected_portfolio_weights)
portfolio_returns
# Out:
#                VFIAX     VVIAX     VTMGX     VEMAX     VIMAX     VSMAX  \
# Date
# 2009-11-24 -0.000489 -0.001068 -0.007073 -0.005268 -0.001542 -0.004171
# 2009-11-25  0.004596  0.005348  0.015138  0.008826  0.008987  0.002285
# 2009-11-27 -0.016938 -0.019149 -0.028947 -0.036745 -0.020598 -0.023556
# 2009-11-30  0.003862  0.006508  0.002710  0.008780  0.004263  0.002335
# 2009-12-01  0.012133  0.011854  0.027928  0.026411  0.015707  0.016693
# ...              ...       ...       ...       ...       ...       ...
# 2022-09-01  0.003169  0.004564 -0.014604 -0.006991 -0.004857 -0.009022
# 2022-09-02 -0.010677 -0.008139 -0.003120 -0.006747 -0.006469 -0.006106
# 2022-09-06 -0.004047 -0.003435 -0.006260 -0.008269 -0.003080 -0.006814
# 2022-09-07  0.018382  0.015128  0.007087  0.005658  0.023115  0.023282
# 2022-09-08  0.006731  0.007923  0.003909 -0.002369  0.009595  0.010222
#
#                VIPSX     VSBSX
# Date
# 2009-11-24  0.000772  0.000500
# 2009-11-25  0.003858  0.000500
# 2009-11-27  0.001537  0.000499
# 2009-11-30  0.001535  0.000499
# 2009-12-01 -0.001533  0.000000
# ...              ...       ...
# 2022-09-01 -0.008494 -0.001026
# 2022-09-02  0.006231  0.002053
# 2022-09-06 -0.008514 -0.001537
# 2022-09-07  0.003903  0.001026
# 2022-09-08 -0.006221 -0.001025
#
# [3219 rows x 8 columns]

# %%
# Adjust the invested balance by the fund return until the next contribution

# For each day in range, multiply by fund return
# loop of returns 

#debug_print(f'The next transaction date at the beginning of the function is {next_transaction}')

for date in transaction_range:
    debug_print(f'Date: {date}')
       
    # ignore any dates before investment start date
    if date < portfolio_investment_start_date:
        continue
    
    try:
        # Look up whether investing and record data points for investment
        if investment_dates.loc[date]['months_to_invest'] > 0:
            
            # how much are we investing
            months_to_invest = investment_dates.loc[date]['months_to_invest']
            
            debug_print(f"months to invest: {months_to_invest}")

            # monthly amount for this year
            # Locate the contribution limit for the contribution date
            year = str(date.year)
            ira_contribution_limit = ira_contr_limits.loc[year]['ira_limit'][0]

            debug_print(f'The IRA contribution limit for {year} is {ira_contribution_limit}.')

            # Amount of this transaction                     
            trans_amt = months_to_invest * ira_contribution_limit/12

            debug_print(f'We are investing ${trans_amt}.')

            # Credit holding account for the year
            
            debug_print(f'The holding account balance is: ${holding_account}')
            debug_print(f'The holding account was last funded: {holding_acct_funded}')

            # If the holding account has never been funded, credit
            if holding_acct_funded == None or holding_acct_funded.year < float(year):
                holding_account = credit_holding_acct(holding_account, ira_contribution_limit)
                
                debug_print(f'The holding account has been funded: ${holding_account}')

                holding_acct_funded = date

                debug_print(f'The holding account was last funded: {holding_acct_funded}')      
       
            # Validate investment amount and update holding account balance 

            # If the holding account is zero:
            if holding_account <= 0:
                investment_account.loc[date] = investment_account.iloc[-1] * (1 + portfolio_returns.loc[date])
                print("The holding account has zero funds. The portfolio return has been added to the previous day's balance.")

            # If the holding account has enough funds:
            elif trans_amt <= holding_account:
                # first transaction
                if date == portfolio_investment_start_date:

                    investment_account.loc[date] = trans_amt * (selected_portfolio_weights.iloc[0].values /100)

                    debug_print('The first contribution has been invested.')
                    debug_print(investment_account)
                
                # Subsequent transactions add to the previous days balance
                else: 
                    # Check for any skipped contributions and add all up to this month
                    trans_amt = max(trans_amt, max(holding_account - ((12 - date.month) * ira_contribution_limit/12), 0))
                    
                    debug_print(f'We are now investing ${trans_amt}.')
                    
                    new_account_value = investment_account.iloc[-1].sum() + trans_amt
                    investment_account.loc[date] = new_account_value * selected_portfolio_weights.iloc[0].values /100
                    
                    debug_print('The contribution has been invested.')
                    debug_print(investment_account)
                    
                # update holding account balance
                holding_account = debit_holding_acct(holding_account, trans_amt)
                debug_print(f'The holding account balance is: ${holding_account}')

            # If the holding account has some funds, but not enough for the full transaction:         
            else: 
                new_account_value = investment_account.iloc[-1].sum() + holding_account
                investment_account.loc[date] = new_account_value * selected_portfolio_weights.iloc[0].values /100

                # update holding account balance
                trans_amt = holding_account
                holding_account = debit_holding_acct(holding_account, trans_amt)
                print('There were insufficient funds in the holding account to fully complete the transaction.')
                print(f'{holding_account} has been added to the investment portfolio.')
                debug_print(f'The holding account balance is: ${holding_account}')       
    
    # Handle portfolio return adjustments for dates without a contribution
    except: 
        try:
            investment_account.loc[date] = investment_account.iloc[-1] * (1 + portfolio_returns.loc[date])
            debug_print('The account increased by portfolio return.')
            
        except:
            # handle holidays
            investment_account.loc[date] = investment_account.iloc[-1]
            debug_print('The account balance rolled over from previous day.')

debug_print(f'The investment account balance is now ${investment_account.iloc[-1].sum()} and the holding account is ${holding_account: .2f}.')
# Out:
# Date: 2013-01-01 00:00:00
# months to invest: 1
# The IRA contribution limit for 2013 is 5500.
# We are investing $458.3333333333333.
# The holding account balance is: $0
# The holding account was last funded: None
# The holding account has been funded: $5500
# The holding account was last funded: 2013-01-01 00:00:00
# The first contribution has been invested.
#             VFIAX  VVIAX  VTMGX  VEMAX      VIMAX      VSMAX      VIPSX  \
# 2013-01-01  68.75  68.75  68.75   27.5  22.916667  18.333333  91.666667
#
#                 VSBSX
# 2013-01-01  91.666667
# The holding account balance is: $5041.666666666667
# Date: 2013-01-02 00:00:00
# The account increased by portfolio return.
# Date: 2013-01-03 00:00:00
# The account increased by portfolio return.
# Date: 2013-01-04 00:00:00
# The account increased by portfolio return.
# Date: 2013-01-07 00:00:00
# The account increased by portfolio return.
# Date: 2013-01-08 00:00:00
# The account increased by portfolio return.
# Date: 2013-01-09 00:00:00
# The account increased by portfolio return.
# Date: 2013-01-10 00:00:00
# The account increased by portfolio return.
# Date: 2013-01
00:00:00
# The account increased by portfolio return.
# Date: 2013-03-05 00:00:00
# The account increased by portfolio return.
# Date: 2013-03-06 00:00:00
# The account increased by portfolio return.
# Date: 2013-03-07 00:00:00
# The account increased by portfolio return.
# Date: 2013-03-08 00:00:00
# The account increased by portfolio return.
# Date: 2013-03-11 00:00:00
# The account increased by portfolio return.
# Date: 2013-03-12 00:00:00
# The account increased by portfolio return.
# Date: 2013-03-13 00:00:00
# The account increased by portfolio return.
# Date: 2013-03-14 00:00:00
# The account increased by portfolio return.
# Date: 2013-03-15 00:00:00
# The account increased by portfolio return.
# Date: 2013-03-18 00:00:00
# The account increased by portfolio return.
# Date: 2013-03-19 00:00:00
# The account increased by portfolio return.
# Date: 2013-03-20 00:00:00
# The account increased by portfolio return.
# Date: 2013-03-21 00:00:00
# The account increased by portfolio return.
# Date: 2013-03-22 00:00:00
# The account increased by portfolio return.
# Date: 2013-03-25 00:00:00
# The account increased by portfolio return.
# Date: 2013-03-26 00:00:00
# The account increased by portfolio return.
# Date: 2013-03-27 00:00:00
# The account increased by portfolio return.
# Date: 2013-03-28 00:00:00
# The account increased by portfolio return.
# Date: 2013-03-29 00:00:00
# The account balance rolled over from previous day.
# Date: 2013-04-01 00:00:00
# months to invest: 1
# The IRA contribution limit for 2013 is 5500.
# We are investing $458.3333333333333.
# The holding account balance is: $4125.0
# The holding account was last funded: 2013-01-01 00:00:00
# We are now investing $458.3333333333335.
# The contribution has been invested.
#                  VFIAX       VVIAX       VTMGX       VEMAX      VIMAX  \
# 2013-01-01   68.750000   68.750000   68.750000   27.500000  22.916667
# 2013-01-02   70.513631   70.459005   70.093246   28.038188  23.444804
# 2013-01-03   70.367099   70.399038   69.421623   28.015764  23.467277
# 2013-01-04   70.707261   70.908742   69.910077   28.030714  23.640327
# 2013-01-07   70.487463   70.638898   69.604792   27.881216  23.566163
# ...                ...         ...         ...         ...        ...
# 2013-03-26  213.518334  213.877421  210.337360   81.284031  71.644931
# 2013-03-27  213.399792  213.709670  209.082155   81.535261  71.695134
# 2013-03-28  214.274012  214.548409  210.158057   81.672290  72.222306
# 2013-03-29  214.274012  214.548409  210.158057   81.672290  72.222306
# 2013-04-01  279.444536  279.444536  279.444536  111.777814  93.148179
#
#                 VSMAX       VIPSX       VSBSX
# 2013-01-01  18.333333   91.666667   91.666667
# 2013-01-02  18.825250   91.288143   91.666667
# 2013-01-03  18.829981   90.720351   91.666667
# 2013-01-04  18.976609   90.846524   91.666667
# 2013-01-07  18.919849   91.098875   91.666667
# ...               ...         ...         ...
# 2013-03-26  57.737497  276.575557  277.341693
# 2013-03-27  57.830391  276.384036  277.341693
# 2013-03-28  58.029437  276.384036  277.341693
# 2013-03-29  58.029437  276.384036  277.341693
# 2013-04-01  74.518543  372.592715  372.592715
#
# [65 rows x 8 columns]
# The holding account balance is: $3666.6666666666665
# Date: 2013-04-02 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-03 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-04 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-05 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-08 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-09 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-10 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-11 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-12 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-15 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-16 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-17 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-18 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-19 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-22 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-23 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-24 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-25 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-26 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-29 00:00:00
# The account increased by portfolio return.
# Date: 2013-04-30 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-01 00:00:00
# months to invest: 1
# The IRA contribution limit for 2013 is 5500.
# We are investing $458.3333333333333.
# The holding account balance is: $3666.6666666666665
# The holding account was last funded: 2013-01-01 00:00:00
# We are now investing $458.3333333333333.
# The contribution has been invested.
#                  VFIAX       VVIAX       VTMGX       VEMAX       VIMAX  \
# 2013-01-01   68.750000   68.750000   68.750000   27.500000   22.916667
# 2013-01-02   70.513631   70.459005   70.093246   28.038188   23.444804
# 2013-01-03   70.367099   70.399038   69.421623   28.015764   23.467277
# 2013-01-04   70.707261   70.908742   69.910077   28.030714   23.640327
# 2013-01-07   70.487463   70.638898   69.604792   27.881216   23.566163
# ...                ...         ...         ...         ...         ...
# 2013-04-25  283.831166  284.591038  291.719883  112.468580   95.051330
# 2013-04-26  283.326519  284.262530  291.719883  111.777814   94.561244
# 2013-04-29  285.364566  286.014553  295.089593  112.625569   95.124840
# 2013-04-30  286.082723  286.233537  296.533738  113.850099   95.623090
# 2013-05-01  353.935560  353.935560  353.935560  141.574224  117.978520
#
#                 VSMAX       VIPSX       VSBSX
# 2013-01-01  18.333333   91.666667   91.666667
# 2013-01-02  18.825250   91.288143   91.666667
# 2013-01-03  18.829981   90.720351   91.666667
# 2013-01-04  18.976609   90.846524   91.666667
# 2013-01-07  18.919849   91.098875   91.666667
# ...               ...         ...         ...
# 2013-04-25  74.794282  374.911760  372.776172
# 2013-04-26  74.484075  375.942445  372.959629
# 2013-04-29  75.035553  375.427090  372.776172
# 2013-04-30  75.483626  374.654083  372.776172
# 2013-05-01  94.382816  471.914080  471.914080
#
# [87 rows x 8 columns]
# The holding account balance is: $3208.333333333333
# Date: 2013-05-02 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-03 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-06 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-07 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-08 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-09 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-10 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-13 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-14 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-15 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-16 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-17 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-20 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-21 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-22 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-23 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-24 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-27 00:00:00
# The account balance rolled over from previous day.
# Date: 2013-05-28 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-29 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-30 00:00:00
# The account increased by portfolio return.
# Date: 2013-05-31 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-03 00:00:00
# months to invest: 1
# The IRA contribution limit for 2013 is 5500.
# We are investing $458.3333333333333.
# The holding account balance is: $3208.333333333333
# The holding account was last funded: 2013-01-01 00:00:00
# We are now investing $458.3333333333333.
# The contribution has been invested.
#                  VFIAX       VVIAX       VTMGX       VEMAX       VIMAX  \
# 2013-01-01   68.750000   68.750000   68.750000   27.500000   22.916667
# 2013-01-02   70.513631   70.459005   70.093246   28.038188   23.444804
# 2013-01-03   70.367099   70.399038   69.421623   28.015764   23.467277
# 2013-01-04   70.707261   70.908742   69.910077   28.030714   23.640327
# 2013-01-07   70.487463   70.638898   69.604792   27.881216   23.566163
# ...                ...         ...         ...         ...         ...
# 2013-05-28  372.041977  372.830368  353.646627  141.260059  123.277724
# 2013-05-29  369.472629  370.639666  351.046279  139.571378  122.258647
# 2013-05-30  370.902749  372.419627  352.490920  139.139387  122.931234
# 2013-05-31  365.594437  366.805951  345.267745  137.097261  121.473954
# 2013-06-03  422.553687  422.553687  422.553687  169.021475  140.851229
#
#                  VSMAX       VIPSX       VSBSX
# 2013-01-01   18.333333   91.666667   91.666667
# 2013-01-02   18.825250   91.288143   91.666667
# 2013-01-03   18.829981   90.720351   91.666667
# 2013-01-04   18.976609   90.846524   91.666667
# 2013-01-07   18.919849   91.098875   91.666667
# ...                ...         ...         ...
# 2013-05-28  100.773090  454.063129  471.217684
# 2013-05-29   99.806866  453.738559  471.217684
# 2013-05-30  100.553497  452.115770  471.217684
# 2013-05-31   99.675105  451.791200  470.985596
# 2013-06-03  112.680983  563.404916  563.404916
#
# [110 rows x 8 columns]
# The holding account balance is: $2749.9999999999995
# Date: 2013-06-04 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-05 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-06 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-07 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-10 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-11 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-12 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-13 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-14 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-17 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-18 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-19 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-20 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-21 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-24 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-25 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-26 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-27 00:00:00
# The account increased by portfolio return.
# Date: 2013-06-28 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-01 00:00:00
# months to invest: 1
# The IRA contribution limit for 2013 is 5500.
# We are investing $458.3333333333333.
# The holding account balance is: $2749.9999999999995
# The holding account was last funded: 2013-01-01 00:00:00
# We are now investing $458.3333333333333.
# The contribution has been invested.
#                  VFIAX       VVIAX       VTMGX       VEMAX       VIMAX  \
# 2013-01-01   68.750000   68.750000   68.750000   27.500000   22.916667
# 2013-01-02   70.513631   70.459005   70.093246   28.038188   23.444804
# 2013-01-03   70.367099   70.399038   69.421623   28.015764   23.467277
# 2013-01-04   70.707261   70.908742   69.910077   28.030714   23.640327
# 2013-01-07   70.487463   70.638898   69.604792   27.881216   23.566163
# ...                ...         ...         ...         ...         ...
# 2013-06-25  407.460501  408.922940  395.507458  149.207836  136.842114
# 2013-06-26  411.470464  412.996505  397.614939  152.017593  138.131186
# 2013-06-27  414.032403  415.973317  402.883709  154.246027  139.739563
# 2013-06-28  412.278057  413.936549  401.478710  156.619796  139.325635
# 2013-07-01  479.465202  479.465202  479.465202  191.786081  159.821734
#
#                  VSMAX       VIPSX       VSBSX
# 2013-01-01   18.333333   91.666667   91.666667
# 2013-01-02   18.825250   91.288143   91.666667
# 2013-01-03   18.829981   90.720351   91.666667
# 2013-01-04   18.976609   90.846524   91.666667
# 2013-01-07   18.919849   91.098875   91.666667
# ...                ...         ...         ...
# 2013-06-25  109.355157  532.666377  562.017241
# 2013-06-26  110.050102  535.497545  562.294786
# 2013-06-27  111.762651  539.542104  562.572332
# 2013-06-28  111.539275  540.350992  562.572332
# 2013-07-01  127.857387  639.286936  639.286936
#
# [130 rows x 8 columns]
# The holding account balance is: $2291.666666666666
# Date: 2013-07-02 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-03 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-04 00:00:00
# The account balance rolled over from previous day.
# Date: 2013-07-05 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-08 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-09 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-10 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-11 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-12 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-15 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-16 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-17 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-18 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-19 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-22 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-23 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-24 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-25 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-26 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-29 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-30 00:00:00
# The account increased by portfolio return.
# Date: 2013-07-31 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-01 00:00:00
# months to invest: 1
# The IRA contribution limit for 2013 is 5500.
# We are investing $458.3333333333333.
# The holding account balance is: $2291.666666666666
# The holding account was last funded: 2013-01-01 00:00:00
# We are now investing $458.3333333333333.
# The contribution has been invested.
#                  VFIAX       VVIAX       VTMGX       VEMAX       VIMAX  \
# 2013-01-01   68.750000   68.750000   68.750000   27.500000   22.916667
# 2013-01-02   70.513631   70.459005   70.093246   28.038188   23.444804
# 2013-01-03   70.367099   70.399038   69.421623   28.015764   23.467277
# 2013-01-04   70.707261   70.908742   69.910077   28.030714   23.640327
# 2013-01-07   70.487463   70.638898   69.604792   27.881216   23.566163
# ...                ...         ...         ...         ...         ...
# 2013-07-26  502.718641  503.673285  502.711977  196.276464  166.954834
# 2013-07-29  500.882869  502.047398  498.560787  194.149443  166.254978
# 2013-07-30  501.076103  501.686075  498.975918  193.676761  166.995209
# 2013-07-31  501.076103  502.047398  499.806140  192.908688  167.493173
# 2013-08-01  560.935125  560.935125  560.935125  224.374050  186.978375
#
#                  VSMAX       VIPSX       VSBSX
# 2013-01-01   18.333333   91.666667   91.666667
# 2013-01-02   18.825250   91.288143   91.666667
# 2013-01-03   18.829981   90.720351   91.666667
# 2013-01-04   18.976609   90.846524   91.666667
# 2013-01-07   18.919849   91.098875   91.666667
# ...                ...         ...         ...
# 2013-07-26  134.453768  640.718208  640.233055
# 2013-07-29  133.723951  639.764027  640.233055
# 2013-07-30  134.201141  639.764027  640.233055
# 2013-07-31  134.566039  643.103571  640.233055
# 2013-08-01  149.582700  747.913500  747.913500
#
# [153 rows x 8 columns]
# The holding account balance is: $1833.3333333333328
# Date: 2013-08-02 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-05 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-06 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-07 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-08 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-09 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-12 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-13 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-14 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-15 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-16 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-19 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-20 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-21 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-22 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-23 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-26 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-27 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-28 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-29 00:00:00
# The account increased by portfolio return.
# Date: 2013-08-30 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-02 00:00:00
# months to invest: 1
# The IRA contribution limit for 2013 is 5500.
# We are investing $458.3333333333333.
# The holding account balance is: $1833.3333333333328
# The holding account was last funded: 2013-01-01 00:00:00
# We are now investing $458.3333333333333.
# The contribution has been invested.
#                  VFIAX       VVIAX       VTMGX       VEMAX       VIMAX  \
# 2013-01-01   68.750000   68.750000   68.750000   27.500000   22.916667
# 2013-01-02   70.513631   70.459005   70.093246   28.038188   23.444804
# 2013-01-03   70.367099   70.399038   69.421623   28.015764   23.467277
# 2013-01-04   70.707261   70.908742   69.910077   28.030714   23.640327
# 2013-01-07   70.487463   70.638898   69.604792   27.881216   23.566163
# ...                ...         ...         ...         ...         ...
# 2013-08-27  536.829979  533.406994  554.015713  213.005595  178.922017
# 2013-08-28  538.432233  534.803341  552.631795  211.984465  179.320403
# 2013-08-29  539.571593  535.601276  552.631795  213.822484  180.102429
# 2013-08-30  537.898166  534.404412  547.557562  215.252058  179.054808
# 2013-09-02  615.260860  615.260860  615.260860  246.104344  205.086953
#
#                  VSMAX       VIPSX       VSBSX
# 2013-01-01   18.333333   91.666667   91.666667
# 2013-01-02   18.825250   91.288143   91.666667
# 2013-01-03   18.829981   90.720351   91.666667
# 2013-01-04   18.976609   90.846524   91.666667
# 2013-01-07   18.919849   91.098875   91.666667
# ...                ...         ...         ...
# 2013-08-27  143.104466  745.680925  747.544880
# 2013-08-28  143.442195  742.890245  747.176260
# 2013-08-29  144.424675  741.773931  747.176260
# 2013-08-30  142.521110  739.541355  747.176260
# 2013-09-02  164.069563  820.347813  820.347813
#
# [175 rows x 8 columns]
# The holding account balance is: $1374.9999999999995
# Date: 2013-09-03 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-04 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-05 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-06 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-09 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-10 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-11 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-12 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-13 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-16 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-17 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-18 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-19 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-20 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-23 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-24 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-25 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-26 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-27 00:00:00
# The account increased by portfolio return.
# Date: 2013-09-30 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-01 00:00:00
# months to invest: 1
# The IRA contribution limit for 2013 is 5500.
# We are investing $458.3333333333333.
# The holding account balance is: $1374.9999999999995
# The holding account was last funded: 2013-01-01 00:00:00
# We are now investing $458.3333333333333.
# The contribution has been invested.
#                  VFIAX       VVIAX       VTMGX       VEMAX       VIMAX  \
# 2013-01-01   68.750000   68.750000   68.750000   27.500000   22.916667
# 2013-01-02   70.513631   70.459005   70.093246   28.038188   23.444804
# 2013-01-03   70.367099   70.399038   69.421623   28.015764   23.467277
# 2013-01-04   70.707261   70.908742   69.910077   28.030714   23.640327
# 2013-01-07   70.487463   70.638898   69.604792   27.881216   23.566163
# ...                ...         ...         ...         ...         ...
# 2013-09-25  635.379881  630.877746  662.429124  266.729784  214.990618
# 2013-09-26  637.701343  631.337078  665.020797  265.717961  215.801845
# 2013-09-27  635.135530  628.581175  663.465813  264.005651  214.939918
# 2013-09-30  631.347961  624.906564  658.800811  261.515034  214.382201
# 2013-10-01  700.962738  700.962738  700.962738  280.385095  233.654246
#
#                  VSMAX       VIPSX       VSBSX
# 2013-01-01   18.333333   91.666667   91.666667
# 2013-01-02   18.825250   91.288143   91.666667
# 2013-01-03   18.829981   90.720351   91.666667
# 2013-01-04   18.976609   90.846524   91.666667
# 2013-01-07   18.919849   91.098875   91.666667
# ...                ...         ...         ...
# 2013-09-25  173.400545  834.587784  821.966614
# 2013-09-26  174.284159  827.777371  821.966614
# 2013-09-27  173.647956  827.777371  821.966614
# 2013-09-30  173.435883  828.396516  821.966614
# 2013-10-01  186.923397  934.616983  934.616983
#
# [196 rows x 8 columns]
# The holding account balance is: $916.6666666666663
# Date: 2013-10-02 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-03 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-04 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-07 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-08 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-09 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-10 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-11 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-14 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-15 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-16 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-17 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-18 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-21 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-22 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-23 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-24 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-25 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-28 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-29 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-30 00:00:00
# The account increased by portfolio return.
# Date: 2013-10-31 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-01 00:00:00
# months to invest: 1
# The IRA contribution limit for 2013 is 5500.
# We are investing $458.3333333333333.
# The holding account balance is: $916.6666666666663
# The holding account was last funded: 2013-01-01 00:00:00
# We are now investing $458.3333333333333.
# The contribution has been invested.
#                  VFIAX       VVIAX       VTMGX       VEMAX       VIMAX  \
# 2013-01-01   68.750000   68.750000   68.750000   27.500000   22.916667
# 2013-01-02   70.513631   70.459005   70.093246   28.038188   23.444804
# 2013-01-03   70.367099   70.399038   69.421623   28.015764   23.467277
# 2013-01-04   70.707261   70.908742   69.910077   28.030714   23.640327
# 2013-01-07   70.487463   70.638898   69.604792   27.881216   23.566163
# ...                ...         ...         ...         ...         ...
# 2013-10-28  729.446175  730.382697  723.999076  290.886104  240.142612
# 2013-10-29  733.572908  734.475906  725.096070  292.126392  241.546004
# 2013-10-30  730.029324  730.894360  723.450580  292.126392  239.595862
# 2013-10-31  727.293113  727.824478  719.611207  290.803401  239.012624
# 2013-11-01  784.262997  784.262997  784.262997  313.705199  261.420999
#
#                  VSMAX        VIPSX        VSBSX
# 2013-01-01   18.333333    91.666667    91.666667
# 2013-01-02   18.825250    91.288143    91.666667
# 2013-01-03   18.829981    90.720351    91.666667
# 2013-01-04   18.976609    90.846524    91.666667
# 2013-01-07   18.919849    91.098875    91.666667
# ...                ...          ...          ...
# 2013-10-28  192.336014   943.005460   935.537356
# 2013-10-29  193.012592   942.306404   935.537356
# 2013-10-30  190.982870   941.607414   935.077170
# 2013-10-31  190.494227   939.510245   935.537356
# 2013-11-01  209.136799  1045.683997  1045.683997
#
# [219 rows x 8 columns]
# The holding account balance is: $458.333333333333
# Date: 2013-11-04 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-05 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-06 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-07 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-08 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-11 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-12 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-13 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-14 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-15 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-18 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-19 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-20 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-21 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-22 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-25 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-26 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-27 00:00:00
# The account increased by portfolio return.
# Date: 2013-11-28 00:00:00
# The account balance rolled over from previous day.
# Date: 2013-11-29 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-02 00:00:00
# months to invest: 1
# The IRA contribution limit for 2013 is 5500.
# We are investing $458.3333333333333.
# The holding account balance is: $458.333333333333
# The holding account was last funded: 2013-01-01 00:00:00
# There were insufficient funds in the holding account to fully complete the transaction.
# 0.0 has been added to the investment portfolio.
# The holding account balance is: $0.0
# Date: 2013-12-03 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-04 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-05 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-06 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-09 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-10 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-11 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-12 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-13 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-16 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-17 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-18 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-19 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-20 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-23 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-24 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-25 00:00:00
# The account balance rolled over from previous day.
# Date: 2013-12-26 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-27 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-30 00:00:00
# The account increased by portfolio return.
# Date: 2013-12-31 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-01 00:00:00
# months to invest: 1
# The IRA contribution limit for 2014 is 5500.
# We are investing $458.3333333333333.
# The holding account balance is: $0.0
# The holding account was last funded: 2013-01-01 00:00:00
# The holding account has been funded: $5500.0
# The holding account was last funded: 2014-01-01 00:00:00
# We are now investing $458.3333333333333.
# The contribution has been invested.
#                  VFIAX       VVIAX       VTMGX       VEMAX       VIMAX  \
# 2013-01-01   68.750000   68.750000   68.750000   27.500000   22.916667
# 2013-01-02   70.513631   70.459005   70.093246   28.038188   23.444804
# 2013-01-03   70.367099   70.399038   69.421623   28.015764   23.467277
# 2013-01-04   70.707261   70.908742   69.910077   28.030714   23.640327
# 2013-01-07   70.487463   70.638898   69.604792   27.881216   23.566163
# ...                ...         ...         ...         ...         ...
# 2013-12-26  877.642109  872.194373  865.551937  332.077381  291.094002
# 2013-12-27  877.538664  872.782316  871.462392  338.913975  290.879064
# 2013-12-30  877.435220  872.194373  875.402654  340.723665  291.416376
# 2013-12-31  880.951621  875.428006  876.716117  341.427428  292.705937
# 2014-01-01  934.788688  934.788688  934.788688  373.915475  311.596229
#
#                  VSMAX        VIPSX        VSBSX
# 2013-01-01   18.333333    91.666667    91.666667
# 2013-01-02   18.825250    91.288143    91.666667
# 2013-01-03   18.829981    90.720351    91.666667
# 2013-01-04   18.976609    90.846524    91.666667
# 2013-01-07   18.919849    91.098875    91.666667
# ...                ...          ...          ...
# 2013-12-26  233.271256  1127.123347  1145.426677
# 2013-12-27  233.226856  1126.255642  1145.426677
# 2013-12-30  233.404489  1128.858758  1145.991496
# 2013-12-31  234.115005  1126.255642  1145.991496
# 2014-01-01  249.276983  1246.384917  1246.384917
#
# [262 rows x 8 columns]
# The holding account balance is: $5041.666666666667
# Date: 2014-01-02 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-03 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-06 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-07 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-08 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-09 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-10 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-13 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-14 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-15 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-16 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-17 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-20 00:00:00
# The account balance rolled over from previous day.
# Date: 2014-01-21 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-22 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-23 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-24 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-27 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-28 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-29 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-30 00:00:00
# The account increased by portfolio return.
# Date: 2014-01-31 00:00:00
# The account increased by portfolio return.
# Date: 2014-02-03 00:00:00
# months to invest: 1
# The IRA contribution limit for 2014 is 5500.
# We are investing $458.3333333333333.
# The holding account balance is: $5041.666666666667
# The holding account was last funded: 2014-01-01 00:00:00
# We are now investing $458.33333333333394.
# The contribution has been invested.
#                  VFIAX       VVIAX       VTMGX       VEMAX       VIMAX  \
# 2013-01-01   68.750000   68.750000   68.750000   27.500000   22.916667
# 2013-01-02   70.513631   70.459005   70.093246   28.038188   23.444804
# 2013-01-03   70.367099   70.399038   69.421623   28.015764   23.467277
# 2013-01-04   70.707261   70.908742   69.910077   28.030714   23.640327
# 2013-01-07   70.487463   70.638898   69.604792   27.881216   23.566163
# ...                ...         ...         ...         ...         ...
# 2014-01-28  907.298161  907.479523  908.180463  349.031836  305.167089
# 2014-01-29  898.134568  899.945975  901.178274  345.728684  302.467287
# 2014-01-30  908.285805  907.479523  902.578739  348.371193  305.807713
# 2014-01-31  902.469453  901.201536  892.075455  346.829734  304.412060
# 2014-02-03  985.648683  985.648683  985.648683  394.259473  328.549561
#
#                  VSMAX        VIPSX        VSBSX
# 2013-01-01   18.333333    91.666667    91.666667
# 2013-01-02   18.825250    91.288143    91.666667
# 2013-01-03   18.829981    90.720351    91.666667
# 2013-01-04   18.976609    90.846524    91.666667
# 2013-01-07   18.919849    91.098875    91.666667
# ...                ...          ...          ...
# 2014-01-28  244.643233  1266.549855  1247.613399
# 2014-01-29  241.758955  1270.390791  1247.613399
# 2014-01-30  245.447039  1270.390791  1247.613399
# 2014-01-31  244.170390  1273.271561  1248.227698
# 2014-02-03  262.839649  1314.198245  1314.198245
#
# [285 rows x 8 columns]
# The holding account balance is: $4583.333333333333
# Date: 2014-02-04 00:00:00
# The account increased by portfolio return.
# Date: 2014-02-05 00:00:00
# The account increased by portfolio return.
# Date: 2014-02-06 00:00:00
# The account increased by portfolio return.
# Date: 2014-02-07 00:00:00
# The account increased by portfolio return.
# Date: 2014-02-10 00:00:00
# ...
# 2013-01-01    68.750000    68.750000    68.750000    27.500000    22.916667
# 2013-01-02    70.513631    70.459005    70.093246    28.038188    23.444804
# 2013-01-03    70.367099    70.399038    69.421623    28.015764    23.467277
# 2013-01-04    70.707261    70.908742    69.910077    28.030714    23.640327
# 2013-01-07    70.487463    70.638898    69.604792    27.881216    23.566163
# ...                 ...          ...          ...          ...          ...
# 2022-04-26  8780.072697  9193.419223  8784.853956  3466.875504  2954.400063
00:00:00
# The account increased by portfolio return.
# Date: 2022-06-03 00:00:00
# The account increased by portfolio return.
# Date: 2022-06-06 00:00:00
# The account increased by portfolio return.
# Date: 2022-06-07 00:00:00
# The account increased by portfolio return.
# Date: 2022-06-08 00:00:00
# The account increased by portfolio return.
# Date: 2022-06-09 00:00:00
# The account increased by portfolio return.
# Date: 2022-06-10 00:00:00
# The account increased by portfolio return.
# Date: 2022-06-13 00:00:00
# The account increased by portfolio return.
# Date: 2022-06-14 00:00:00
# The account increased by portfolio return.
# Date: 2022-06-15 00:00:00
# The account increased by portfolio return.
# Date: 2022-06-16 00:00:00
# The account increased by portfolio return.
# Date: 2022-06-17 00:00:00
# The account increased by portfolio return.
# Date: 2022-06-20 00:00:00
# The account balance rolled over from previous day.
# Date: 2022-06-21 00:00:00
# The account increased by portfolio return.
# Date: 2022-06-22 00:00:00
# The account increased by portfolio return.
# Date: 2022-06-23 00:00:00
# The account increased by portfolio return.
# Date: 2022-06-24 00:00:00
# The account increased by portfolio return.
# Date: 2022-06-27 00:00:00
# The account increased by portfolio return.
# Date: 2022-06-28 00:00:00
# The account increased by portfolio return.
# Date: 2022-06-29 00:00:00
# The account increased by portfolio return.
# Date: 2022-06-30 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-01 00:00:00
# months to invest: 1
# The IRA contribution limit for 2022 is 6000.
# We are investing $500.0.
# The holding account balance is: $3000.0
# The holding account was last funded: 2022-01-03 00:00:00
# We are now investing $500.0.
# The contribution has been invested.
#                   VFIAX        VVIAX        VTMGX        VEMAX        VIMAX  \
# 2013-01-01    68.750000    68.750000    68.750000    27.500000    22.916667
# 2013-01-02    70.513631    70.459005    70.093246    28.038188    23.444804
# 2013-01-03    70.367099    70.399038    69.421623    28.015764    23.467277
# 2013-01-04    70.707261    70.908742    69.910077    28.030714    23.640327
# 2013-01-07    70.487463    70.638898    69.604792    27.881216    23.566163
# ...                 ...          ...          ...          ...          ...
# 2022-06-27  8868.404454  8735.885668  8534.502147  3621.960910  2923.724976
# 2022-06-28  8654.621669  8657.364405  8502.489639  3607.505776  2874.231423
# 2022-06-29  8649.467542  8625.622078  8444.867246  3597.181074  2856.804093
# 2022-06-30  8575.097858  8583.855557  8374.440216  3568.271593  2833.683772
# 2022-07-01  8825.921870  8825.921870  8825.921870  3530.368748  2941.973957
#
#                   VSMAX         VIPSX         VSBSX
# 2013-01-01    18.333333     91.666667     91.666667
# 2013-01-02    18.825250     91.288143     91.666667
# 2013-01-03    18.829981     90.720351     91.666667
# 2013-01-04    18.976609     90.846524     91.666667
# 2013-01-07    18.919849     91.098875     91.666667
# ...                 ...           ...           ...
# 2022-06-27  2342.553295  12162.424012  12326.327549
# 2022-06-28  2304.808939  12116.284140  12326.327549
# 2022-06-29  2281.520059  12088.600569  12345.223732
# 2022-06-30  2259.301758  11793.305920  12351.522459
# 2022-07-01  2353.579165  11767.895827  11767.895827
#
# [2479 rows x 8 columns]
# The holding account balance is: $2500.0
# Date: 2022-07-04 00:00:00
# The account balance rolled over from previous day.
# Date: 2022-07-05 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-06 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-07 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-08 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-11 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-12 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-13 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-14 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-15 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-18 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-19 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-20 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-21 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-22 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-25 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-26 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-27 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-28 00:00:00
# The account increased by portfolio return.
# Date: 2022-07-29 00:00:00
# The account increased by portfolio return.
# Date: 2022-08-01 00:00:00
# months to invest: 1
# The IRA contribution limit for 2022 is 6000.
# We are investing $500.0.
# The holding account balance is: $2500.0
# The holding account was last funded: 2022-01-03 00:00:00
# We are now investing $500.0.
# The contribution has been invested.
#                   VFIAX        VVIAX        VTMGX        VEMAX        VIMAX  \
# 2013-01-01    68.750000    68.750000    68.750000    27.500000    22.916667
# 2013-01-02    70.513631    70.459005    70.093246    28.038188    23.444804
# 2013-01-03    70.367099    70.399038    69.421623    28.015764    23.467277
# 2013-01-04    70.707261    70.908742    69.910077    28.030714    23.640327
# 2013-01-07    70.487463    70.638898    69.604792    27.881216    23.566163
# ...                 ...          ...          ...          ...          ...
# [2523 rows x 8 columns]
# The holding account balance is: $1500.0
# Date: 2022-09-02 00:00:00
# The account increased by portfolio return.
# Date: 2022-09-05 00:00:00
# The account balance rolled over from previous day.
# Date: 2022-09-06 00:00:00
# The account increased by portfolio return.
# Date: 2022-09-07 00:00:00
# The account increased by portfolio return.
# Date: 2022-09-08 00:00:00
# The account increased by portfolio return.
# Date: 2022-09-09 00:00:00
# The account balance rolled over from previous day.
# Date: 2022-09-12 00:00:00
# The account balance rolled over from previous day.
# Date: 2022-09-13 00:00:00
# The account balance rolled over from previous day.
# Date: 2022-09-14 00:00:00
# The account balance rolled over from previous day.
# Date: 2022-09-15 00:00:00
# The account balance rolled over from previous day.
# The investment account balance is now $60729.96560407082 and the holding account is $ 1500.00.

# %%
display(investment_account.head(3))
display(investment_account.loc['2012-12-31':'2013-01-03'])
display(investment_account.tail())
# Out:
#                 VFIAX      VVIAX      VTMGX      VEMAX      VIMAX      VSMAX  \
# 2013-01-01  68.750000  68.750000  68.750000  27.500000  22.916667  18.333333
# 2013-01-02  70.513631  70.459005  70.093246  28.038188  23.444804  18.825250
# 2013-01-03  70.367099  70.399038  69.421623  28.015764  23.467277  18.829981
#
#                 VIPSX      VSBSX
# 2013-01-01  91.666667  91.666667
# 2013-01-02  91.288143  91.666667
# 2013-01-03  90.720351  91.666667
#                 VFIAX      VVIAX      VTMGX      VEMAX      VIMAX      VSMAX  \
# 2013-01-01  68.750000  68.750000  68.750000  27.500000  22.916667  18.333333
# 2013-01-02  70.513631  70.459005  70.093246  28.038188  23.444804  18.825250
# 2013-01-03  70.367099  70.399038  69.421623  28.015764  23.467277  18.829981
#
#                 VIPSX      VSBSX
# 2013-01-01  91.666667  91.666667
# 2013-01-02  91.288143  91.666667
# 2013-01-03  90.720351  91.666667
#                  VFIAX        VVIAX       VTMGX        VEMAX        VIMAX  \
# 2022-09-09  9166.52663  9177.151361  9088.25194  3587.049131  3094.533368
# 2022-09-12  9166.52663  9177.151361  9088.25194  3587.049131  3094.533368
# 2022-09-13  9166.52663  9177.151361  9088.25194  3587.049131  3094.533368
# 2022-09-14  9166.52663  9177.151361  9088.25194  3587.049131  3094.533368
# 2022-09-15  9166.52663  9177.151361  9088.25194  3587.049131  3094.533368
#
#                   VSMAX         VIPSX         VSBSX
# 2022-09-09  2469.191073  12042.257132  12105.004969
# 2022-09-12  2469.191073  12042.257132  12105.004969
# 2022-09-13  2469.191073  12042.257132  12105.004969
# 2022-09-14  2469.191073  12042.257132  12105.004969
# 2022-09-15  2469.191073  12042.257132  12105.004969

# %%
x = investment_account.index
y = investment_account.sum(axis=1)

fig = go.Figure(data=go.Scatter(x=x, y=y))

fig.update_layout(
    title=f'{portfolio_selection}: {portfolio_investment_start_date:%d-%b-%Y} - {today:%d-%b-%Y} - ({timing} investment)',
    xaxis_title="Year",
    yaxis_title="Account Balance",
    #legend_title="Legend Title",
    #font=dict(
     #   family="Courier New, monospace",
     #   size=18,
     #   color="RebeccaPurple"
    )

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10300\2539287275.py in <module>
#      15     )
#      16
# ---> 17 fig.show()
#
# c:\ProgramData\Anaconda3\envs\tf-p3.7\lib\site-packages\plotly\basedatatypes.py in show(self, *args, **kwargs)
#    3396         import plotly.io as pio
#    3397
# -> 3398         return pio.show(self, *args, **kwargs)
#    3399
#    3400     def to_json(self, *args, **kwargs):
#
# c:\ProgramData\Anaconda3\envs\tf-p3.7\lib\site-packages\plotly\io\_renderers.py in show(fig, renderer, validate, **kwargs)
#     395         if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
#     396             raise ValueError(
# --> 397                 "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398             )
#     399
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
save_pickle(investment_account, f'./resources/{portfolio_selection}_{timing}.pkl')

# %%
save_image(fig, f'./resources/images/{portfolio_selection}_{timing}.png')

# %%
# Overlay

# Fidelity Charts
path = f"./resources/fidelity_index_focused_models_ml_model_1.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

fid_model_1 = dataframe

path = f"./resources/fidelity_index_focused_models_annual.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

fid_annual = dataframe

path = f"./resources/fidelity_index_focused_models_monthly.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

fid_monthly = dataframe

# Betterment Charts
path = f"./resources/betterment_ml_model_1.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

betterment_model_1 = dataframe

path = f"./resources/betterment_annual.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

betterment_annual = dataframe

path = f"./resources/betterment_monthly.pkl"

pkl_file = open(Path(path), 'rb')
dataframe = pickle.load(pkl_file)
pkl_file.close()

betterment_monthly = dataframe

# %%
# Plot

plot_portfolio = 'Fidelity'

x = {
    'Fidelity':[fid_monthly.index, fid_model_1.index, fid_annual.index],
    'Betterment':[betterment_monthly.index, betterment_model_1.index, betterment_annual.index]
}

y = {
    'Fidelity':[fid_monthly.sum(axis=1), fid_model_1.sum(axis=1), fid_annual.sum(axis=1)],
    'Betterment':[betterment_monthly.sum(axis=1), betterment_model_1.sum(axis=1), betterment_annual.sum(axis=1)]
}


fig = go.Figure()

fig.add_scatter(x=x[plot_portfolio][2], y=y[plot_portfolio][2].values, mode='lines', name='Annual')

fig.add_scatter(x=x[plot_portfolio][1], y=y[plot_portfolio][1].values, mode='lines', name='ML Model 1')

fig.add_scatter(x=x[plot_portfolio][0], y=y[plot_portfolio][0].values, mode='lines', name='Monthly')

fig.update_layout(
    title=f'{portfolio_selection}: {portfolio_investment_start_date:%d-%b-%Y} - {today:%d-%b-%Y}',
    xaxis_title="Year",
    yaxis_title="Account Balance",
    legend_title="Contribution Strategy",
    #font=dict(
     #   family="Courier New, monospace",
     #   size=18,
     #   color="RebeccaPurple"
    )

fig.show()

# %%
save_image(fig, f'./resources/images/{portfolio_selection}_overlay.png')
